# %% [markdown]
# <a href="https://colab.research.google.com/github/thanit456/NeuroSummary/blob/master/Project_NLP_LSTM_encoder_decoder_with_Attention_without_Teacher_forcing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA First Thai Gov

# %%
thaigov_dataset = pd.read_csv("/content/drive/Shared drives/NeuroSummary/data/1_24_thaigov.csv")

# %%
thaigov_dataset.iloc[30]
# Out:
# file_name    24/ข่าวทำเนียบรัฐบาล_78.txt
# headline     ﻿รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-นายกฯ ให้กำลังใจบุคลากร สธ. นราธิวาส หลังเกิดเหตุไม่สงบ สั่งดูแลช่วยเหลือระยะสั้น-ยาวอย่างเต็มที่
# content      วันอาทิตย์ที่ 30 ธันวาคม 2561 นายกฯ ให้กำลังใจบุคลากร สธ. นราธิวาส หลังเกิดเหตุไม่สงบ สั่งดูแลช่วยเหลือระยะสั้น-ยาวอย่างเต็มที่ นายกฯ ให้กำลังใจบุคลากร สธ. นราธิวาส หลังเกิดเหตุไม่สงบ สั่งดูแลช่วยเหลือระยะสั้น-ยาวอย่างเต็มที่ นายพุทธิพงษ์ ปุณณกันต์ รองเลขาธิการนายกรัฐมนตรีฝ่ายการเมือง ปฏิบัติหน้าที่โฆษกประจำสำนักนายกรัฐมนตรี เปิดเผยว่า พลเอก ประยุทธ์ จันทร์โอชา นายกรัฐมนตรี ให้กำลังใจหมออนามัยและลูกจ้างของโรงพยาบาลส่งเสริมสุขภาพตำบลบ้านกาหนั๊วะ อ.ระแงะ จ.นราธิวาส หลังเกิดเหตุกลุ่มคนร้ายยึดโรงพยาบาลเพื่อก่อเหตุความไม่สงบ พร้อมทั้งสั่งการให้กระทรวงสาธารณสุขและทางจังหวัดติดตามให้ความช่วยเหลือดูแลอย่างเต็มที่ "นายกฯ รับทราบถึงความมุ่งมั่นตั้งใจในการทำงานของบุคลากรสาธารณสุข เพื่อให้บริการสุขภาพและพัฒนาคุณภาพชีวิตของคนในพื้นที่อย่างเข้มแข็ง และไม่ปรารถนาให้เกิดอันตรายหรือความสูญเสียจากการใช้ความรุนแรงไม่ว่ารูปแบบใดทั้งสิ้น" โฆษกประจำสำนักนายกรัฐมนตรีกล่าวว่า นายกรัฐมนตรีได้มอบหมายให้กระทรวงสาธารณสุขเป็นหน่วยงานกลางประสานผู้ที่เกี่ยวข้อง เพื่อหารือถึงความเป็นไปได้ในการจัดตั้งกองทุนเยียวยาบุคลากรสาธารณสุขชายแดนใต้ การดูแลสิทธิสวัสดิการต่าง ๆ และมาตรการรักษาความปลอดภัยแก่ผู้ปฏิบัติงานในพื้นที่โดยเร่งด่วนที่สุด ........................................................................ สำนักโฆษก
# reference    https://www.thaigov.go.th/news/contents/details/17842
# Name: 30, dtype: object

# %%
type(thaigov_dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
thaigov_dataset.iloc[:]

# %%
thaigov_dataset.loc[1,'content'][-100:]
# Out:
# 'ะราชามาประยุกต์ใช้อย่างเหมาะสม .............................. กลุ่มประชาสัมพันธ์และเผยแพร่ สำนักโฆษก'

# %% [markdown]
# # Data Prep

# %% [markdown]
# ### Cleaning
# - remove special case

# %%
import re
def basic_cleaner(text) :
  special_char = '!|"|#|%|&|\'|,|-|/|:|;|<|=|>|@|_|`|~|\.|\$'.split("|")# type(result)
  nstr = text
  for special in special_char :
    nstr = re.sub(special+"+",special.replace('\\',''),nstr)
  nstr = re.sub("|^||'","",nstr).replace("|","").replace("*","").replace("  "," ").replace(u'\xa0', u' ')
  return nstr

# %%
df_content = thaigov_dataset.loc[:,'content']

# %%
df_content_clean = df_content.apply(basic_cleaner)
df_content_diff = df_content_clean[df_content != df_content_clean]

# %%
text = "asdasd. kk.... . .15%b%^&%$#$% 2$ $$$"
re.sub("\$+","$",text)
# Out:
# 'asdasd. kk.... . .15%b%^&%$#$% 2$ $'

# %% [markdown]
# ### Tokenize sentence by pythainlp

# %%
df_content_diff[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-21f87acd427d> in <module>()
# ----> 1 df_content_diff[:10]
#
# NameError: name 'df_content_diff' is not defined

# %%
df_content_clean.to_csv("b_thaigov_cleaner.csv",index=False)

# %%
# !ls
# Out:
# b_thaigov_cleaner.csv  b_thaigov.csv  drive  sample_data

# %%
  # !cp -r b_thaigov_cleaner.csv /content/drive/Shared\ drives/NeuroSummary/data/b_data_playground/b_thaigov_cleaner.csv

# %%
thaigov_dataset.loc[:,'content']  = df_content_clean

# %%
thaigov_dataset.loc[1,'content'][-101:]
# Out:
# 'กับสิ่งแวดล้อม  น้อมนำศาสตร์พระราชามาประยุกต์ใช้อย่างเหมาะสม . กลุ่มประชาสัมพันธ์และเผยแพร่ สำนักโฆษก'

# %%
thaigov_dataset.to_csv("b_thaigov.csv", index=False)

# %%
# !cp -r b_thaigov.csv /content/drive/Shared\ drives/NeuroSummary/data/b_data_playground/b_thaigov.csv

# %% [markdown]
# # EDA

# %%
import pickle
with open(r"/content/drive/Shared drives/NeuroSummary/data/b_data_playground/b_thaigov_segmented.pickle", "rb") as input_file:
  thaigov_clean = pickle.load(input_file)

# %%
x = pd.DataFrame(thaigov_clean)

# %%
x.shape
# Out:
# (17367, 1)

# %%
df_content = thaigov_clean
df_headline = thaigov_dataset.headline

# %%
thaigov_dataset.content = x[0]

# %%
type(thaigov_dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
type(thaigov_dataset.content[0])
# Out:
# list

# %%
len(df_headline[0])
# Out:
# 151

# %%
df_headline[0]
# Out:
# '\ufeffรัฐบาลไทย-ข่าวทำเนียบรัฐบาล-ธอส.ประกาศมาตรการบรรเทาความเดือดร้อนลูกค้าจากพายุโซนร้อนปาบึกเพิ่มเติม พิจารณาจ่ายค่าสินไหมทุกรายเร่งด่วนสูงสุด 20,000 บาท'

# %%
df_content[:10]
# Out:
# array([list(['วันจันทร์ที่ 7 มกราคม 2562 ธอส.ประกาศมาตรการบรรเทาความเดือดร้อนลูกค้าจากพายุโซนร้อนปาบึกเพิ่มเติม ', 'พิจารณาจ่ายค่าสินไหมทุกรายเร่งด่วนสูงสุด 20,000 บาท ธนาคารอาคารสงเคราะห์ (ธอส.) ประกาศมาตรการบรรเทาความเดือดร้อนให้กับลูกค้าของธนาคารที่ได้รับผลกระทบจากอิทธิพลของพายุโซนร้อน “ปาบึก” เพิ่มเติมด้วย ', '“มาต
คประมงไทยและสินค้าประมงไทย พล.ต.อ.อดุลย์ฯ กล่าวต่อว่า การให้สัตยาบันอนุสัญญาดังกล่าวเป็นการแสดงเจตนารมณ์ของไทยในการยกระดับมาตรฐานการคุ้มครองการทำงานบนเรือประมงของทั้งแรงงานไทยและแรงงานต่างด้าวให้ดียิ่งขึ้นและสอดคล้องกับมาตรฐานสากล และป้องกันความเสี่ยงที่แรงงานจะตกอยู่ในสภาพแรงงานบังคับ เนื่องจากอนุสัญญาจะช่วยสร้างหลักประกันให้เกิดสภาพการทำงานที่มีคุณค่าแก่แรงงานประมง เช่น การกำหนดชั่วโมงการทำงาน คุณภาพที่พักอาศัย อาหาร น้ำดื่ม การรักษาพยาบาล ', 'ระบบการตรวจแรงงานและความเป็นอยู่บนเรือประมง เป็นต้น ', 'ซึ่งจะช่วยส่งเสริมการทำประมงที่มีจริยธรรมและมีธรรมาภิบาล ', 'และยังดึงดูดแรงงานให้เข้ามาทำงานในภาคประมงมากขึ้น อันจะช่วยแก้ไขปัญหาการขาดแคลนแรงงานในภาคประมงต่อไปด้วย ', 'ส่วนความเชื่อมโยงกับการปลดใบเหลืองนั้น รัฐบาลไทยได้ผลักดันการทำงานเพื่อระดับการคุ้มครองแรงงานในภาคประมง ควบคู่ไปกับการแก้ไขปัญหา IUU มาอย่างต่อเนื่อง เพื่อให้ไทยมีการทำการประมงอย่างยั่งยืน ', 'ซึ่งเป็นเป้าหมายสูงสุดของรัฐบาล โดยมีการดำเนินมาตรการหลายประการ รวมถึงการจัดระเบียบการทำประมงในช่วง 3-4 ปีที่ผ่านมา โดยเฉพาะการให้สัตยาบันพิธีสารของอนุสัญญาฉบับที่ 29 ว่าด้วยแรงงานบังคับ และอนุสัญญาฉบับที่ 188 จะมีผลทำให้มาตรการทางกฎหมายและการบังคับใช้มีการพัฒนาให้มีประสิทธิภาพเพิ่มมากขึ้นอย่างมาก และเชื่อมั่นว่าเป็นปัจจัยหนึ่งที่ทำให้ไทยได้รับการเลื่อนลำดับประเทศที่มีความพยายามในการแก้ไขปัญหาการค้ามนุษย์จาก Tier 2 Watch List เป็น Tier 2 ในปีที่ผ่านมา ', 'และล่าสุดเมื่อวันที่ 8 ม.ค.62 สหภาพยุโรปได้ประกาศปลดสถานะใบเหลืองของภาคประมงไทย อันแสดงถึงการยอมรับต่อความก้าวหน้าของการแก้ไขปัญหา IUU ของไทย ซึ่งมีการพัฒนามาอย่างต่อเนื่องนับตั้งแต่ไทยได้รับสถานะใบเหลืองเมื่อปี 2558 จนประสบความสำเร็จในการยกระดับอุตสาหกรรมการประมงของไทยทั้งระบบในปัจจุบัน ซึ่งทำให้สหภาพยุโรปยอมรับ ', 'ขณะนี้ไทยมีกลไกแก้ไขปัญหาการทำประมงผิดกฎหมายที่เข้มแข็งที่สุดในภูมิภาค และสามารถเป็นแบบอย่างที่ดีให้กับประเทศต่าง ๆ ที่มีปัญหาเดียวกันได้ ', 'นายกาย ไรเดอร์ (Mr.Guy Ryder) ผู้อำนวยการใหญ่ ILO ได้ก
ระไตรปิฎกฉบับสำหรับประชาชน ฉบับวาระ 100 ปี ชาตกาล อาจารย์ สุชีพ ปุญญานุภาพขึ้น ในวันที่ 26 ธันวาคม 2561 เวลา 14.00 - 16.00 น. ณ อาคาร 100 ปี วัดบวรนิเวศวิหาร โดยได้รับพระเมตตาจาก สมเด็จพระอริยวงศาคตญาณ สมเด็จพระสังฆราช สกลมหาสังฆปริณายก เสด็จเป็นประธานในงานพิธีสมโภชพระไตรปิฎกฯ ', 'ทั้งนี้ ภายในงานดังกล่าว มีนิทรรศการประวัติและผลงานของอาจารย์สุชีพ ปุญญานุภาพ และจัดแสดงหนังสือพระไตรปิฎกฉบับสำหรับประชาชน ฉบับวาระ 100 ปี ชาตกาล อาจารย์สุชีพ ปุญญานุภาพ โดยจัดขึ้นระหว่างวันที่ 26 ธันวาคม 2561 – 12 มกราคม 2562 ', 'นอกจากนี้ในวันที่ 31 ธันวาคม 2561 มีกิจกรรมสวดมนต์ข้ามปี ณ วัดบวรนิเวศวิหาร อีกด้วย รัฐมนตรีว่าการกระทรวงวัฒนธรรม กล่าวอีกว่า หนังสือพระไตรปิฎกฉบับสำหรับประชาชน ', 'เป็นผลงานสำคัญของอาจารย์   สุชีพ และนับเป็นพระไตรปิฎกย่อฉบับสมบูรณ์ฉบับแรกของโลกด้วย ', 'โดยหนังสือพระไตรปิฎกดังกล่าว เป็นการย่อในลักษณะถอดความของพระไตรปิฎกบาลี 45 เล่ม ให้เป็นหนังสือภาษาไทยเพียงเล่มเดียว โดยประมวลไว้ซึ่งเนื้อความหรือสาระของพระไตรปิฎกทั้ง 45 เล่ม อย่างครบถ้วนสมบูรณ์ด้วยถ้อยคำสำนวนที่คนทั่วไปสามารถอ่านและเข้าใจได้ง่าย ', 'ทั้งนี้ คณะกรรมการจัดงานครั้งนี้มีความเห็นว่า ทุกฝ่ายควรจะได้เผยแพร่พระไตรปิฎกฯ ฉบับนี้ให้แพร่หลายไปสู่ประชาชน ', 'เพื่อให้เป็นสมบัติของคนไทย ทำให้ได้รับความรู้ในเรื่องพระไตรปิฎกอย่างสะดวกและทั่วถึงตามที่อาจารย์สุชีพได้ตั้งใจไว้ เพื่อความเจริญมั่นคงของพระพุทธศาสนาและสันติสุขของชาติ ', 'ทั้งนี้ อาจารย์สุชีพ ปุญญานุภาพ เป็นผู้มีคุณูปการต่อพระพุทธศาสนาและการศึกษาของไทยอย่างมาก ', 'เมื่อครั้งยังดำรงอยู่ในสมณเพศได้ศึกษาพระพุทธศาสนาจนสำเร็จเปรียญธรรม 9 ประโยค และศึกษาภาษาและวิชาการต่างๆ อีกมาก ', 'ทำให้มีความรอบรู้อย่างกว้างขวาง และได้บูรณาการความรู้ทั้งทางโลกและทางธรรมสั่งสอนและเผยแผ่พระพุทธศาสนา จนมีชื่อเสียงเป็นที่รู้จักกันทั่วประเทศในนามว่า “สุชีโวภิกขุ” ', 'ทั้งนี้ นับเป็นพระสงฆ์ไทยรูปแรกที่มีชื่อเสียงด้านการเผยแผ่พระพุทธศาสนาแนวใหม่ทั้งแก่ชาวไทยและชาวต่างประเทศ ', 'อีกทั้งเป็นผู้ริเริ่มการอธิบายพุทธธรรมแนวประยุกต์กับวิชาการสมัย
จ ', 'โรงเรียนได้นำไปจัดกิจกรรมการเรียนรู้ดาราศาสตร์ในระดับโรงเรียนและชุมชนอย่างต่อเนื่อง โดยเฉพาะในช่วงที่เกิดปรากฏการณ์สำคัญทางดาราศาสตร์ นายศุภฤกษ์ กล่าวเพิ่มเติมว่า ในปี 2562 สดร. ต่อยอดโครงการมอบกล้องโทรทรรศน์ โดยมุ่งเน้นให้นำไปใช้สำหรับศึกษาและผลิตโครงงานดาราศาสตร์ เกิดเป็นโครงการมอบกล้องโทรทรรศน์และสื่อการเรียนรู้ดาราศาสตร์ เพื่อพัฒนาโครงงานดาราศาสตร์ระดับโรงเรียน สนับสนุนกล้องโทรทรรศน์และสื่อการเรียนรู้ทางดาราศาสตร์แก่โรงเรียนและสถานศึกษา ทั้งภาครัฐและเอกชน สำหรับจัดการเรียนการสอน จัดกิจกรรมทางดาราศาสตร์ สังเกตการณ์วัตถุท้องฟ้าและปรากฏการณ์ทางดาราศาสตร์ที่น่าสนใจ ทั้งในโรงเรียนและชุมชน ', 'และที่สำคัญต้องการกระตุ้นและเพิ่มศักยภาพการทำโครงงานดาราศาสตร์ในระดับโรงเรียนอย่างแพร่หลาย ', 'ซึ่งจะนำมาสู่องค์ความรู้ใหม่ สร้างแรงบันดาลใจให้นักเรียนสนใจใฝ่รู้ในวิทยาศาสตร์ยิ่งขึ้น นอกจากมอบกล้องโทรทรรศน์และสื่อการเรียนรู้ดาราศาสตร์แล้ว สดร. ยังจัดฝึกอบรมการใช้งานกล้องโทรทรรศน์แก่โรงเรียนที่ได้รับคัดเลือกเข้าร่วมโครงการฯ รวมถึงกลุ่มโรงเรียนใน “โครงการกระจายโอกาสการเรียนรู้ดาราศาสตร์ 77 จังหวัดฯ” ที่ดำเนินการมาก่อนหน้านี้ ', 'เพื่อให้ครูได้ฝึกปฏิบัติการการใช้งานกล้องโทรทรรศน์ โดยเน้นไปที่การสังเกตการณ์เพื่อศึกษาโครงงานดาราศาสตร์เป็นหลัก ', 'หวังให้ครูและนักเรียนสามารถกลับไปใช้งานกล้องโทรทรรศน์ได้เองในโรงเรียนให้เกิดประโยชน์สูงสุดอีกด้วย ', 'นายศุภฤกษ์กล่าวปิดท้าย โรงเรียนที่สนใจสมัครเข้าร่วมโครงการฯ ติดตามข้อมูลเพิ่มเติมและดาวน์โหลดสมัครได้ที่ www.narit.or.th รับเพียง 50 โรงเรียนเท่านั้น ', 'หมดเขตส่งใบสมัครวันที่ 25 มกราคม 2562 และประกาศผลการคัดเลือกภายในวันที่ 29 มกราคม 2562 สอบถามโทร. 053-121268-9 ต่อ 305 หรือ 088-2524424 (คุณคมสันต์)'])],
#       dtype=object)

# %%
thaigov_dataset.head()

# %% [markdown]
# # Split Dataset\

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

import re

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook
import copy
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
old_df = pd.read_pickle('/content/drive/Shared drives/NeuroSummary/data/all_deepcut_thaigov_1_24.pkl')
df = pd.DataFrame({'content': old_df['tokenized_deepcut_content'], 'headline': old_df['tokenized_deepcut_headline'], 'class': old_df['class_name']})

# %%
print(old_df.columns)
# Out:
# Index(['file_name', 'raw_content', 'reference', 'headline', 'date', 'content',
#        'tokenized_deepcut_content', 'tokenized_deepcut_headline',
#        'removed_stopwords_content', 'removed_stopwords_headline',
#        'class_name'],
#       dtype='object')

# %%
df_stop = pd.DataFrame({'content': old_df['removed_stopwords_content'], 'headline': old_df['removed_stopwords_headline'], 'class': old_df['class_name']})

# %%
headline_dist = list(map(lambda x: len(x),list(df.headline)))
sns.distplot(headline_dist);

# %%
headline_dist = list(map(lambda x: len(x),list(df_stop.headline)))
sns.distplot(headline_dist);

# %%
content_dist = list(map(lambda x: len(x),list(df.content)))
sns.distplot(content_dist);

# %%
content_dist = list(map(lambda x: len(x),list(df_stop.content)))
sns.distplot(content_dist);

# %%
def remove_space_special(content_arr) :
  return list(filter(lambda x: x not in " (){}!,'`<>=@_:;,\'\"\\”“‘’",np.array(content_arr)))
# def replace_ห
df.headline = df.headline.apply(remove_space_special)
df.content = df.content.apply(remove_space_special)
df_stop.headline = df_stop.headline.apply(remove_space_special)
df_stop.content = df_stop.content.apply(remove_space_special)

# %%
headline_dist = list(map(lambda x: len(x),list(df.headline)))
sns.distplot(headline_dist);

# %%
headline_dist = list(map(lambda x: len(x),list(df_stop.headline)))
sns.distplot(headline_dist);

# %%
content_dist = list(map(lambda x: len(x),list(df.content)))
sns.distplot(content_dist);

# %%
content_dist = list(map(lambda x: len(x),list(df_stop.content)))
sns.distplot(content_dist);

# %%
max_len_headline = max(df.headline.apply(lambda x: len(x)))
print("max len headline : ",max_len_headline)
max_len_content = max(df.content.apply(lambda x: len(x)))
print("max len content : ",max_len_content)

print("df shape :" ,df.shape)
max_len_headline_stop = max(df_stop.headline.apply(lambda x: len(x)))
print("max len headline stop: ",max_len_headline_stop)
max_len_content_stop = max(df_stop.content.apply(lambda x: len(x)))
print("max len content stop: ",max_len_content_stop)
# print("removed stop df shape :" ,df_stop.shape)
# Out:
# max len headline :  48
# max len content :  16373
# df shape : (17367, 3)
# max len headline stop:  39
# max len content stop:  7242

# %%
df = df[df.content.apply(lambda x: len(x) != 0)]
df.shape
# Out:
# (17337, 3)

# %%
import pickle
THAIGOV_PATH = '/content/drive/Shared drives/NeuroSummary/data/b_data_playground/'
with open(THAIGOV_PATH + 'thai_gov_clean_cut.pkl', 'wb') as f:
  pickle.dump(df, f)
with open(THAIGOV_PATH + 'thai_gov_stop_clean_cut.pkl', 'wb') as f:
  pickle.dump(df_stop, f)

# %%
# content_len_dist = [(df.content[df.content.apply(lambda x: len(x) == n)].shape[0],n) for n in range(max_len_content)][0]
# content_len_dist

# %%
headline_len_dist = [(df_stop.headline[df_stop.headline.apply(lambda x: len(x) <= n)].shape[0],n) for n in range(max_len_headline_stop)]
headline_len_dist
# sns.distplot(headline_len_dist);
# len(df.content)
# Out:
# [(0, 0),
#  (9, 1),
#  (41, 2),
#  (147, 3),
#  (357, 4),
#  (802, 5),
#  (1564, 6),
#  (2618, 7),
#  (4100, 8),
#  (5497, 9),
#  (6948, 10),
#  (8376, 11),
#  (9757, 12),
#  (11027, 13),
#  (12117, 14),
#  (13029, 15),
#  (13798, 16),
#  (14471, 17),
#  (15019, 18),
#  (15478, 19),
#  (15870, 20),
#  (16217, 21),
#  (16443, 22),
#  (16683, 23),
#  (16839, 24),
#  (16970, 25),
#  (17068, 26),
#  (17149, 27),
#  (17217, 28),
#  (17263, 29),
#  (17294, 30),
#  (17318, 31),
#  (17334, 32),
#  (17344, 33),
#  (17358, 34),
#  (17360, 35),
#  (17363, 36),
#  (17364, 37),
#  (17366, 38)]

# %%
headline_len_dist = [(df.headline[df.headline.apply(lambda x: len(x) <= n)].shape[0],n) for n in range(max_len_headline)]
headline_len_dist
# sns.distplot(headline_len_dist);
# len(df.content)
# Out:
# [(0, 0),
#  (1, 1),
#  (12, 2),
#  (55, 3),
#  (119, 4),
#  (221, 5),
#  (400, 6),
#  (754, 7),
#  (1184, 8),
#  (1903, 9),
#  (2608, 10),
#  (3346, 11),
#  (4206, 12),
#  (5162, 13),
#  (6111, 14),
#  (7079, 15),
#  (8023, 16),
#  (8928, 17),
#  (9800, 18),
#  (10611, 19),
#  (11340, 20),
#  (11936, 21),
#  (12534, 22),
#  (13061, 23),
#  (13524, 24),
#  (13908, 25),
#  (14342, 26),
#  (14696, 27),
#  (15015, 28),
#  (15336, 29),
#  (15599, 30),
#  (15846, 31),
#  (16064, 32),
#  (16269, 33),
#  (16454, 34),
#  (16614, 35),
#  (16743, 36),
#  (16883, 37),
#  (16970, 38),
#  (17103, 39),
#  (17176, 40),
#  (17225, 41),
#  (17272, 42),
#  (17296, 43),
#  (17316, 44),
#  (17326, 45),
#  (17331, 46),
#  (17336, 47)]

# %%
df = df[df.headline.apply(lambda x: len(x) <= 20)]
df_stop = df_stop[df_stop.headline.apply(lambda x: len(x) <= 20)]

# %%
df.shape
# Out:
# (11340, 3)

# %%
df
# Out:
#                                                  content  ...                    class
# 1      [พลเอก ประยุทธ์ จันทร์โอชา, นายก, รัฐมนตรี, ได...  ...        ข่าวทำเนียบรัฐบาล
# 2      [รมว., แรงงาน, ยื่น, สัตยาบัน, อนุสัญญา, ILO, ...  ...           ด้านความมั่นคง
# 3      [ออมสิน, จัด, โปรพิเศษ, Thailand, Smart, Money...  ...             ด้านเศรษฐกิจ
# 7      [เผย, เป็น, ผล, งาน, สำคัญ, และ, พระไตรปิฎก, ย...  ...  ด้านวัฒนธรรมท่องเที่ยวฯ
# 8      [ศาสตราจารย์พิเศษวิศิษฏ์ วิศิษฏ์สรอรรถ, ปลัด, ...  ...              ด้านกฎหมายฯ
# ...                                                  ...  ...                      ...
# 17359  [นายปรัก สุคน, Mr. Prak Sokhonn, รัฐมนตรี, อาว...  ...        ข่าวทำเนียบรัฐบาล
# 17360  [นายก, รัฐมนตรี, เข้า, ร่วม, ประชุม, เพื่อ, ติ...  ...        ข่าวทำเนียบรัฐบาล
# 17361  [วัน, นี้, 30, ส.ค., 59, เวลา, 09, ., 15, น., ...  ...        ข่าวทำเนียบรัฐบาล
# 17362  [ที่, ประชุม, มี, มติ, เห็น, ชอบ, ร่าง, แผน, ป...  ...        ข่าวทำเนียบรัฐบาล
# 17364  [วัน, นี้, 22, สิงหาคม, 2559, เวลา, 14, ., 00,...  ...        ข่าวทำเนียบรัฐบาล
#
# [11340 rows x 3 columns]

# %%
df_stop
# Out:
#                                                  content  ...              class
# 0      [ธนาคารอาคารสงเคราะห์, ธอส., ประกาศ, มาตรการ, ...  ...       ด้านเศรษฐกิจ
# 1      [พลเอก ประยุทธ์ จันทร์โอชา, นายก, รัฐมนตรี, ปร...  ...  ข่าวทำเนียบรัฐบาล
# 2      [รมว., แรงงาน, ยื่น, สัตยาบัน, อนุสัญญา, ILO, ...  ...     ด้านความมั่นคง
# 3      [ออมสิน, โปรพิเศษ, Thailand, Smart, Money, กรุ...  ...       ด้านเศรษฐกิจ
# 4      [ศ.คลินิก,  นพ.อุดม คชินทร, รมช., ศธ., ประชุม,...  ...      ด้านการศึกษาฯ
# ...                                                  ...  ...                ...
# 17361  [30, ส.ค., 59, เวลา, 09, ., 15, น., บริเวณ, หน...  ...  ข่าวทำเนียบรัฐบาล
# 17362  [ประชุม, มติ, ชอบ, ร่าง, แผน, ดำเนิน, ส่งเสริม...  ...  ข่าวทำเนียบรัฐบาล
# 17363  [22, สิงหาคม, 2559, เวลา, 14, ., 00, น., บริเว...  ...  ข่าวทำเนียบรัฐบาล
# 17364  [22, สิงหาคม, 2559, เวลา, 14, ., 00, น., บริเว...  ...  ข่าวทำเนียบรัฐบาล
# 17365  [25, ส.ค., 59, เวลา, 09, ., 00, น., ตึกสันติไม...  ...  ข่าวทำเนียบรัฐบาล
#
# [15870 rows x 3 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.

# %%
df.headline

# %%
df.content.apply(lambda x : x[:50])

# %%
train_df, val_test_df = train_test_split(df, test_size=0.33, random_state=42)
val_df, test_df = train_test_split(val_test_df, test_size=0.5, random_state=123)

# %%
import pickle
THAIGOV_PATH = '/content/drive/Shared drives/NeuroSummary/data/b_data_playground/thai_gov_split/'
with open(THAIGOV_PATH + 'train.pkl', 'wb') as f:
  pickle.dump(train_df, f)

with open(THAIGOV_PATH + 'val.pkl', 'wb') as f:
  pickle.dump(val_df, f)

with open(THAIGOV_PATH + 'test.pkl', 'wb') as f:
  pickle.dump(test_df, f)

# %%
train_df_stop, val_test_df_stop = train_test_split(df_stop, test_size=0.33, random_state=42)
val_df_stop, test_df_stop = train_test_split(val_test_df_stop, test_size=0.5, random_state=123)

# %%
import pickle
THAIGOV_PATH = '/content/drive/Shared drives/NeuroSummary/data/b_data_playground/thai_gov_split/'
with open(THAIGOV_PATH + 'train_stop.pkl', 'wb') as f:
  pickle.dump(train_df_stop, f)

with open(THAIGOV_PATH + 'val_stop.pkl', 'wb') as f:
  pickle.dump(val_df_stop, f)

with open(THAIGOV_PATH + 'test_stop.pkl', 'wb') as f:
  pickle.dump(test_df_stop, f)

# %% [markdown]
# # Creade Dictionary

# %% [markdown]
# ## load train,val,test_set

# %%
import pickle 
import numpy as np
import keras
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.sequence import pad_sequences
THAIGOV_PATH = '/content/drive/Shared drives/NeuroSummary/data/b_data_playground/thai_gov_split/'

from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Using TensorFlow backend.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **Choose *HAS_STOP_WORD* or *NO_STOP_WORD* `DATASET`**

# %%
with open(THAIGOV_PATH + 'train_v2.pkl', 'rb') as f:
  train_set = pickle.load(f)
with open(THAIGOV_PATH + 'val_v2.pkl', 'rb') as f:
  val_set = pickle.load(f)
with open(THAIGOV_PATH + 'test_v2.pkl', 'rb') as f:
  test_set = pickle.load(f)

# %%
sorted(train_set.content.apply(lambda x : len(x)))[::-1]
# Out:
# [13639,
#  13639,
#  13200,
#  13129,
#  11499,
#  10144,
#  9849,
#  9480,
#  9399,
#  9301,
#  9246,
#  9016,
#  8772,
#  8605,
#  8451,
#  8276,
#  8272,
#  7863,
#  7724,
#  7563,
#  7412,
#  6946,
#  6945,
#  6774,
#  6710,
#  6667,
#  6630,
#  6572,
#  6553,
#  6466,
#  6461,
#  6347,
#  6188,
#  6128,
#  6018,
#  6010,
#  5939,
#  5897,
#  5887,
#  5884,
#  5593,
#  5553,
#  5468,
#  5447,
#  5383,
#  5365,
#  5326,
#  5301,
#  5256,
#  5142,
#  5072,
#  5038,
#  5009,
#  4984,
#  4937,
#  4897,
#  4886,
#  4838,
#  4831,
#  4824,
#  4812,
#  4785,
#  4730,
#  4694,
#  4688,
#  4684,
#  4664,
#  4613,
#  4562,
#  4558,
#  4550,
#  4521,
#  4514,
#  4280,
#  4279,
#  4247,
#  4243,
#  4221,
#  4201,
#  4162,
#  4125,
#  4046,
#  4041,
#  4026,
#  4025,
#  3945,
#  3924,
#  3885,
#  3879,
#  3844,
#  3807,
#  3796,
#  3724,
#  3682,
#  3666,
#  3623,
#  3615,
#  3608,
#  3567,
#  3551,
#  3521,
#  3519,
#  3474,
#  3432,
#  3378,
#  3339,
#  3256,
#  3251,
#  3248,
#  3226,
#  3184,
#  3171,
#  3152,
#  3114,
#  3109,
#  3109,
#  3108,
#  3071,
#  3031,
#  3011,
#  3007,
#  2919,
#  2918,
#  2878,
#  2847,
#  2836,
#  2824,
#  2820,
#  2814,
#  2801,
#  2796,
#  2765,
#  2724,
#  2723,
#  2711,
#  2663,
#  2647,
#  2643,
#  2626,
#  2614,
#  2611,
#  2606,
#  2604,
#  2593,
#  2568,
#  2564,
#  2544,
#  2531,
#  2506,
#  2503,
#  2499,
#  2498,
#  2496,
#  2473,
#  2447,
#  2445,
#  2422,
#  2415,
#  2408,
#  2405,
#  2402,
#  2386,
#  2377,
#  2354,
#  2342,
#  2330,
#  2329,
#  2322,
#  2313,
#  2312,
#  2301,
#  2286,
#  2284,
#  2278,
#  2271,
#  2269,
#  2269,
#  2268,
#  2256,
#  2252,
#  2252,
#  2249,
#  2242,
#  2237,
#  2236,
#  2221,
#  2218,
#  2208,
#  2205,
#  2205,
#  2201,
#  2199,
#  2191,
#  2191,
#  2165,
#  2164,
#  2158,
#  2158,
#  2142,
#  2133,
#  2130,
#  2120,
#  2120,
#  2117,
#  2103,
#  2100,
#  2099,
#  2096,
#  2096,
#  2096,
#  2089,
#  2088,
#  2086,
#  2086,
#  2083,
#  2082,
#  2075,
#  2072,
#  2072,
#  2071,
#  2068,
#  2067,
#  2066,
#  2061,
#  2057,
#  2048,
#  2042,
#  2039,
#  2039,
#  2037,
#  2030,
#  2029,
#  2024,
#  2017,
#  2017,
#  2014,
#  2010,
#  2007,
#  2007,
#  2005,
#  2002,
#  1996,
#  1993,
#  1992,
#  1990,
#  1988,
#  1986,
#  1980,
#  1980,
#  1980,
#  1978,
#  1978,
#  1975,
#  1973,
#  1973,
#  1970,
#  1970,
#  1970,
#  1968,
#  1968,
#  1967,
#  1967,
#  1961,
#  1960,
#  1960,
#  1958,
#  1952,
#  1942,
#  1942,
#  1930,
#  1928,
#  1927,
#  1926,
#  1923,
#  1922,
#  1922,
#  1922,
#  1917,
#  1917,
#  1911,
#  1908,
#  1897,
#  1892,
#  1889,
#  1881,
#  1869,
#  1868,
#  1867,
#  1854,
#  1852,
#  1849,
#  1847,
#  1839,
#  1837,
#  1836,
#  1833,
#  1832,
#  1829,
#  1828,
#  1826,
#  1824,
#  1822,
#  1819,
#  1808,
#  1804,
#  1802,
#  1798,
#  1796,
#  1793,
#  1791,
#  1791,
#  1787,
#  1786,
#  1783,
#  1782,
#  1775,
#  1774,
#  1774,
#  1772,
#  1771,
#  1770,
#  1768,
#  1768,
#  1766,
#  1761,
#  1761,
#  1760,
#  1758,
#  1745,
#  1744,
#  1739,
#  1738,
#  1737,
#  1731,
#  1728,
#  1722,
#  1720,
#  1716,
#  1715,
#  1714,
#  1712,
#  1711,
#  1710,
#  1709,
#  1702,
#  1697,
#  1696,
#  1679,
#  1679,
#  1678,
#  1677,
#  1673,
#  1672,
#  1663,
#  1660,
#  1660,
#  1658,
#  1658,
#  1657,
#  1650,
#  1648,
#  1645,
#  1644,
#  1643,
#  1641,
#  1639,
#  1638,
#  1636,
#  1635,
#  1634,
#  1632,
#  1632,
#  1629,
#  1628,
#  1621,
#  1620,
#  1615,
#  1614,
#  1613,
#  1611,
#  1611,
#  1611,
#  1609,
#  1609,
#  1606,
#  1606,
#  1604,
#  1603,
#  1601,
#  1601,
#  1601,
#  1600,
#  1600,
#  1598,
#  1595,
#  1593,
#  1590,
#  1590,
#  1590,
#  1588,
#  1588,
#  1587,
#  1587,
#  1586,
#  1585,
#  1583,
#  1582,
#  1581,
#  1576,
#  1575,
#  1575,
#  1572,
#  1570,
#  1569,
#  1568,
#  1565,
#  1564,
#  1564,
#  1563,
#  1559,
#  1559,
#  1558,
#  1558,
#  1557,
#  1556,
#  1555,
#  1554,
#  1551,
#  1550,
#  1548,
#  1541,
#  1540,
#  1539,
#  1534,
#  1533,
#  1531,
#  1530,
#  1530,
#  1523,
#  1522,
#  1521,
#  1520,
#  1520,
#  1519,
#  1518,
#  1517,
#  1515,
#  1513,
#  1513,
#  1513,
#  1513,
#  1511,
#  1508,
#  1508,
#  1506,
#  1505,
#  1504,
#  1503,
#  1500,
#  1499,
#  1494,
#  1494,
#  1493,
#  1492,
#  1491,
#  1490,
#  1487,
#  1486,
#  1485,
#  1485,
#  1484,
#  1481,
#  1479,
#  1477,
#  1476,
#  1476,
#  1468,
#  1467,
#  1466,
#  1466,
#  1465,
#  1464,
#  1464,
#  1463,
#  1462,
#  1459,
#  1457,
#  1457,
#  1457,
#  1455,
#  1455,
#  1452,
#  1452,
#  1452,
#  1450,
#  1450,
#  1447,
#  1446,
#  1446,
#  1445,
#  1445,
#  1441,
#  1440,
#  1438,
#  1436,
#  1434,
#  1434,
#  1434,
#  1433,
#  1430,
#  1429,
#  1426,
#  1422,
#  1422,
#  1417,
#  1416,
#  1414,
#  1413,
#  1411,
#  1411,
#  1411,
#  1410,
#  1410,
#  1407,
#  1406,
#  1405,
#  1405,
#  1404,
#  1403,
#  1401,
#  1401,
#  1401,
#  1399,
#  1398,
#  1397,
#  1397,
#  1396,
#  1395,
#  1394,
#  1393,
#  1393,
#  1389,
#  1388,
#  1388,
#  1387,
#  1385,
#  1381,
#  1381,
#  1380,
#  1380,
#  1379,
#  1379,
#  1377,
#  1376,
#  1376,
#  1376,
#  1376,
#  1375,
#  1374,
#  1374,
#  1374,
#  1371,
#  1370,
#  1370,
#  1366,
#  1365,
#  1364,
#  1363,
#  1363,
#  1363,
#  1362,
#  1361,
#  1361,
#  1361,
#  1360,
#  1360,
#  1357,
#  1356,
#  1355,
#  1353,
#  1352,
#  1352,
#  1351,
#  1350,
#  1350,
#  1349,
#  1348,
#  1347,
#  1345,
#  1345,
#  1344,
#  1344,
#  1344,
#  1341,
#  1340,
#  1340,
#  1339,
#  1339,
#  1334,
#  1334,
#  1331,
#  1330,
#  1330,
#  1328,
#  1328,
#  1327,
#  1327,
#  1326,
#  1326,
#  1325,
#  1325,
#  1324,
#  1322,
#  1322,
#  1322,
#  1322,
#  1321,
#  1321,
#  1321,
#  1320,
#  1319,
#  1319,
#  1318,
#  1318,
#  1316,
#  1316,
#  1312,
#  1311,
#  1310,
#  1308,
#  1308,
#  1304,
#  1304,
#  1302,
#  1302,
#  1298,
#  1298,
#  1297,
#  1296,
#  1295,
#  1294,
#  1294,
#  1293,
#  1291,
#  1289,
#  1289,
#  1288,
#  1286,
#  1285,
#  1283,
#  1282,
#  1279,
#  1279,
#  1278,
#  1278,
#  1278,
#  1276,
#  1273,
#  1271,
#  1270,
#  1270,
#  1270,
#  1270,
#  1269,
#  1268,
#  1268,
#  1267,
#  1267,
#  1266,
#  1266,
#  1263,
#  1263,
#  1263,
#  1262,
#  1261,
#  1261,
#  1261,
#  1261,
#  1260,
#  1260,
#  1259,
#  1259,
#  1258,
#  1257,
#  1257,
#  1256,
#  1256,
#  1256,
#  1254,
#  1253,
#  1252,
#  1252,
#  1251,
#  1251,
#  1251,
#  1251,
#  1247,
#  1245,
#  1244,
#  1244,
#  1244,
#  1244,
#  1242,
#  1241,
#  1241,
#  1241,
#  1240,
#  1239,
#  1238,
#  1238,
#  1238,
#  1238,
#  1238,
#  1238,
#  1237,
#  1236,
#  1236,
#  1235,
#  1235,
#  1232,
#  1231,
#  1231,
#  1231,
#  1231,
#  1230,
#  1228,
#  1227,
#  1227,
#  1227,
#  1227,
#  1226,
#  1226,
#  1226,
#  1225,
#  1224,
#  1224,
#  1224,
#  1223,
#  1222,
#  1222,
#  1220,
#  1218,
#  1218,
#  1217,
#  1216,
#  1215,
#  1215,
#  1214,
#  1213,
#  1212,
#  1212,
#  1212,
#  1211,
#  1211,
#  1211,
#  1210,
#  1210,
#  1209,
#  1209,
#  1209,
#  1207,
#  1207,
#  1206,
#  1206,
#  1206,
#  1206,
#  1206,
#  1205,
#  1204,
#  1204,
#  1204,
#  1204,
#  1204,
#  1204,
#  1204,
#  1203,
#  1202,
#  1199,
#  1199,
#  1199,
#  1198,
#  1197,
#  1197,
#  1197,
#  1197,
#  1196,
#  1195,
#  1195,
#  1195,
#  1195,
#  1194,
#  1194,
#  1194,
#  1194,
#  1194,
#  1193,
#  1193,
#  1193,
#  1192,
#  1190,
#  1190,
#  1189,
#  1188,
#  1187,
#  1187,
#  1187,
#  1187,
#  1186,
#  1186,
#  1185,
#  1185,
#  1184,
#  1183,
#  1183,
#  1183,
#  1182,
#  1182,
#  1182,
#  1182,
#  1181,
#  1181,
#  1181,
#  1180,
#  1180,
#  1180,
#  1180,
#  1178,
#  1178,
#  1178,
#  1177,
#  1177,
#  1177,
#  1176,
#  1176,
#  1175,
#  1174,
#  1174,
#  1174,
#  1173,
#  1172,
#  1172,
#  1171,
#  1171,
#  1170,
#  1170,
#  1169,
#  1168,
#  1168,
#  1168,
#  1168,
#  1168,
#  1167,
#  1167,
#  1167,
#  1167,
#  1165,
#  1165,
#  1162,
#  1162,
#  1162,
#  1161,
#  1161,
#  1160,
#  1159,
#  1158,
#  1157,
#  1156,
#  1156,
#  1156,
#  1156,
#  1155,
#  1155,
#  1154,
#  1154,
#  1153,
#  1153,
#  1151,
#  1151,
#  1149,
#  1149,
#  1148,
#  1147,
#  1147,
#  1147,
#  1146,
#  1146,
#  1146,
#  1145,
#  1145,
#  1144,
#  1143,
#  1143,
#  1142,
#  1142,
#  1141,
#  1141,
#  1140,
#  1139,
#  1139,
#  1139,
#  1138,
#  1138,
#  1137,
#  1136,
#  1136,
#  1135,
#  1135,
#  1135,
#  1133,
#  1133,
#  1133,
#  1133,
#  1133,
#  1131,
#  1131,
#  1129,
#  1129,
#  1128,
#  1128,
#  1128,
#  1127,
#  1127,
#  1126,
#  1126,
#  1124,
#  1123,
#  1123,
#  1122,
#  1121,
#  1121,
#  1121,
#  1120,
#  1120,
#  1120,
#  1120,
#  1119,
#  1119,
#  1119,
#  1118,
#  1118,
#  1118,
#  1117,
#  1117,
#  1116,
#  1116,
#  1115,
#  1115,
#  1114,
#  1114,
#  1113,
#  1113,
#  1113,
#  1113,
#  1112,
#  1112,
#  1110,
#  1110,
#  1108,
#  1108,
#  1107,
#  1107,
#  1107,
#  1107,
#  1106,
#  1106,
#  1106,
#  1105,
#  1104,
#  1104,
#  1103,
#  1103,
#  1103,
#  1103,
#  1103,
#  1102,
#  1102,
#  1101,
#  1101,
#  1101,
#  1100,
#  1099,
#  1098,
#  1097,
#  1097,
#  1097,
#  1097,
#  1096,
#  1096,
#  1096,
#  1096,
#  1095,
#  1095,
#  1095,
#  1095,
#  1095,
#  1094,
#  1093,
#  1093,
#  1093,
#  1093,
#  ...]

# %%
# with open(THAIGOV_PATH + 'train_stop.pkl', 'rb') as f:
#   train_set = pickle.load(f)
# with open(THAIGOV_PATH + 'val_stop.pkl', 'rb') as f:
#   val_set = pickle.load(f)
# with open(THAIGOV_PATH + 'test_stop.pkl', 'rb') as f:
#   test_set = pickle.load(f)

# %%
## ! use only n first words for headline generation
def use_firt_n_words(df_content, n):
  new_ls = []
  for content in df_content:
    new_ls.append(content[:n])
  return new_ls

#define_n_first_words
n_first_content = 500
n_first_headline = 50

#trim sentence
words_train_contents = use_firt_n_words(train_set['content'], n=n_first_content)
words_train_headlines = use_firt_n_words(train_set['headline'], n=n_first_headline)
words_val_contents = use_firt_n_words(val_set['content'], n=n_first_content)
words_val_headlines = use_firt_n_words(val_set['headline'], n=n_first_headline)
words_test_contents = use_firt_n_words(test_set['content'], n=n_first_content)
words_test_headlines = use_firt_n_words(test_set['headline'], n=n_first_headline)

# generate gold_sum
gold_sum_train = list(map(lambda x: " ".join(x),words_train_headlines))
gold_sum_val = list(map(lambda x: " ".join(x),words_val_headlines))
gold_sum_test = list(map(lambda x: " ".join(x),words_test_headlines))

# %%
import collections
def create_index(input_data,threshold):
    input_text = [data for data in input_data]
    # counts of word type has to be above or equal threshold
    words = [word for sublist in input_text for word in sublist]
    print("words :",words)
    word_count_all = list()
    word_count = list()
    #use set and len to get the number of unique words
    word_count_all.extend(collections.Counter(words).most_common(len(set(words))))
    unkcnt = 0
    for (word,cnt) in word_count_all:
      if cnt >= threshold:
        word_count.append((word,cnt))
      else:
        unkcnt+=cnt
    #include a token for unknown word
    word_count.append(("UNK",unkcnt))
    #print out 10 most frequent words
    # print("top 10: ",word_count[:10])
    # print("bottom 10: ",word_count[-10:])
    dictionary = dict()
    dictionary["for_keras_zero_padding"] = 0
    for word in word_count:
      dictionary[word[0]] = len(dictionary)
    dictionary['<s>'] = len(dictionary) 
    dictionary['</s>'] = len(dictionary)
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    
    return dictionary, reverse_dictionary
dict_t, rev_dict_t = create_index(input_data=words_train_contents+words_train_headlines,threshold=0)
# dict_stop_t, rev_dict_stop_t = create_index(input_data=words_70_train_stop_contents+words_20_train_stop_headlines,threshold=0)
print('Vocab size (Content): ',len(dict_t))
# print('Vocab stop ?size (Content): ',len(dict_stop_t))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Vocab size (Content):  69070

# %%
# # with open(THAIGOV_PATH + f'attention_predict_result_v2_unit:{400}_batch:{64}.pkl', 'wb') as f:
# #   pickle.dump(result, f)
# with open('/content/' + f'dict_t_200_20_v2.pkl', 'wb') as f:
#   pickle.dump(dict_t, f)
# with open('/content/' + f'rev_dict_t_200_20_v2.pkl', 'wb') as f:
#   pickle.dump(rev_dict_t, f)

# %%
print('Vocab size (Content): ',len(dict_t))
# print('Vocab stop size (Content): ',len(dict_stop_t))
maxlen_output = n_first_headline
maxlen = n_first_content
vocab_size = len(dict_t)
output_vocab_size = vocab_size

# m=15000
# Tx=maxlen
# Ty=maxlen_output
# Out:
# Vocab size (Content):  69070

# %%
def convert(input_data,dictionary) :
  X = list()
  for data in input_data:
    sub_data = []
    for word in data:
      if word in dictionary:
        sub_data.append(dictionary[word])
      else:
        sub_data.append(dictionary["UNK"])
    X.append(sub_data)
  return np.array(X)

# %%
X_train = convert(words_train_contents,dict_t)
y_train = convert(words_train_headlines,dict_t)
X_val = convert(words_val_contents,dict_t)
y_val = convert(words_val_headlines,dict_t)
X_test = convert(words_test_contents,dict_t)
y_test = convert(words_test_headlines,dict_t)

# %%
X_train = pad_sequences(X_train,maxlen=maxlen,padding='post')
y_train = pad_sequences(y_train,maxlen=maxlen_output,padding='post') 
X_val = pad_sequences(X_val,maxlen=maxlen,padding='post')
y_val = pad_sequences(y_val,maxlen=maxlen_output,padding='post') 
X_test = pad_sequences(X_test,maxlen=maxlen,padding='post')
# y_test = pad_sequences(y_test,maxlen=maxlen_output,padding='post') 
# y_val = list(y_val.swapaxes(0,1))

# %%
# # y_train = to_categorical(y_train, vocab_size)
# # y_val = to_categorical(y_val, vocab_size)
# # y_test = to_categorical(y_test, vocab_size)
# y_train = np.array(keras.utils.to_categorical(y_train, num_classes=vocab_size))
# y_val = np.array(keras.utils.to_categorical(y_val, num_classes=vocab_size))
# # y_test = np.array(keras.utils.to_categorical(y_test, num_classes=vocab_size))

# %% [markdown]
# # Create Model

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
# %matplotlib inline
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, Concatenate, Permute, Dot, Input, LSTM, Multiply,Add,Conv1D,GRU,TimeDistributed
from tensorflow.keras.layers import RepeatVector, Dense, Activation, Lambda, Embedding,concatenate,Reshape
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.activations import softmax
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.models import load_model, Model
import tensorflow.keras.backend as K
import numpy as np

# %%
maxlen_output = n_first_headline
maxlen = n_first_content
vocab_size = len(dict_t)
output_vocab_size = vocab_size
# m=15000
# Tx=maxlen
# Ty=maxlen_output

# %%
from random import randrange
from tensorflow.keras.activations import softmax
from tensorflow.keras.layers import Lambda
def compute_context(a, s_prev, n_unit):
    repeator = RepeatVector(maxlen)
    s_prev = repeator(s_prev)
    def softMaxAxis1(x):
      return softmax(x,axis=1)
    concatenator = Concatenate(axis=-1)
    activatorSoftmax = Lambda(softMaxAxis1) 
    dotor = Dot(axes = 1) 
    concat = concatenator([s_prev, a[:,:,n_unit//2:]])
    fattn_1 = Dense(n_unit//2)
    fattn_2 = Dense(maxlen_output, activation = "tanh")
    fattn_3 = Dense(1, activation = "relu")
    M = fattn_2(fattn_1(concat))
    attention_scores = activatorSoftmax(fattn_3(M))
    context = dotor([attention_scores,a[:,:,:n_unit//2]])
    return context # return whatever you need to complete this homework 

def define_attention_models(n_input=maxlen,n_output=maxlen_output,n_units=32) :
  #define training encoder model
  encoder_inputs = Input(shape=(maxlen,))
  embed = Embedding(vocab_size, n_units)
  encoder_embedding = embed(encoder_inputs)
  encoder_LSTM  = LSTM(n_units,return_state=True,return_sequences = True)
  h, s, c = encoder_LSTM(encoder_embedding)
  decoder_LSTM_cell = LSTM(n_units, return_state=True, dropout=dropout_rate)
  decoder_dense  = Dense(vocab_size, activation='softmax')
  outputs = list()
  # decoder_output = []
  for t in range(maxlen_output) :
    context = compute_context(h,c,n_units)    
    s, _, c = decoder_LSTM_cell(context, initial_state=[s,c])
    decoder_output = decoder_dense(s)
    outputs.append(decoder_output)
  model = Model(inputs=encoder_inputs,outputs=outputs)
  return model,encoder_LSTM,decoder_LSTM_cell

# %%
import numpy as np
import math
from tensorflow.keras.utils import Sequence

class SequenceGenerator(Sequence):

    def __init__(self, x_set, y_set, batch_size,num_classes,pred_option):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.pred_option = pred_option

    def __len__(self):
        return math.ceil(len(self.x) / self.batch_size)

    def __getitem__(self, idx):
        #  y = list(map(lambda mem :np.append(mem,[len(dict_t)-1]),y))
        # y_shift = list(map(lambda mem :np.append([len(dict_t)-2], mem[:-1]),y))

        # y_shift = pad_sequences(y_shift,maxlen=maxlen_output,padding='post')
        # X = np.array(keras.utils.to_categorical(X, num_classes=self.n_classes), dtype=object)
        # y_shift = np.array(keras.utils.to_categorical(y_shift, num_classes=self.n_classes))
        batch_x = self.x[idx * self.batch_size:(idx + 1) *
        self.batch_size]
        if(self.pred_option) :
          return np.array(batch_x)
        batch_y = self.y[idx * self.batch_size:(idx + 1) *
        self.batch_size]
        batch_y = np.array(tf.keras.utils.to_categorical(batch_y, self.num_classes))
        # s0 = np.zeros((self.batch_size, 64))
        # c0 = np.zeros((self.batch_size, 64))
        # return [np.array(batch_x),s0,c0], list(batch_y.swapaxes(0,1))
        return np.array(batch_x), list(batch_y.swapaxes(0,1))

# %%
drive_path = '/content/drive/Shared drives/NeuroSummary/evaluation/result/thai_gov/50_20/logB'
optimizer = 'rmsprop'
lr=0.01
epoch_num=30
batch_size = 64
# units=256
dropout_rate = 0.0
type_dataset = "train"

# %%
# from my_classes import DataGenerator

# Parameters
params = {
          'dimX': maxlen,
          'dimY': maxlen_output,
          'batch_size': batch_size,
          'n_classes': vocab_size,
          'n_channels': 1,
          'shuffle': True
          }
          
training_generator_seq = SequenceGenerator(np.array(X_train),np.array(y_train),batch_size,vocab_size,0)
validation_generator_seq = SequenceGenerator(np.array(X_val),np.array(y_val),batch_size,vocab_size,0)

# %%
model = define_attention_models(n_units=1024)
model[0].summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 500)]        0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 500, 1024)    70727680    input_4[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   [(None, 500, 1024),  8392704     embedding_3[0][0]
# __________________________________________________________________________________________________
# repeat_vector_113 (RepeatVector (None, 500, 1024)    0           lstm_6[0][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_225 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_113 (Concatenate)   (None, 500, 1536)    0           repeat_vector_113[0][0]
#                                                                  tf_op_layer_strided_slice_225[0][
# __________________________________________________________________________________________________
# dense_343 (Dense)               (None, 500, 512)     786944      concatenate_113[0][0]
# __________________________________________________________________________________________________
# dense_344 (Dense)               (None, 500, 50)      25650       dense_343[0][0]
# __________________________________________________________________________________________________
# dense_345 (Dense)               (None, 500, 1)       51          dense_344[0][0]
# __________________________________________________________________________________________________
# lambda_113 (Lambda)             (None, 500, 1)       0           dense_345[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_226 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_113 (Dot)                   (None, 1, 512)       0           lambda_113[0][0]
#                                                                  tf_op_layer_strided_slice_226[0][
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   [(None, 1024), (None 6295552     dot_113[0][0]
#                                                                  lstm_6[0][1]
#                                                                  lstm_6[0][2]
#                                                                  dot_114[0][0]
#                                                                  lstm_7[0][0]
#                                                                  lstm_7[0][2]
#                                                                  dot_115[0][0]
#                                                                  lstm_7[1][0]
#                                                                  lstm_7[1][2]
#                                                                  dot_116[0][0]
#                                                                  lstm_7[2][0]
#                                                                  lstm_7[2][2]
#                                                                  dot_117[0][0]
#                                                                  lstm_7[3][0]
#                                                                  lstm_7[3][2]
#                                                                  dot_118[0][0]
#                                                                  lstm_7[4][0]
#                                                                  lstm_7[4][2]
#                                                                  dot_119[0][0]
#                                                                  lstm_7[5][0]
#                                                                  lstm_7[5][2]
#                                                                  dot_120[0][0]
#                                                                  lstm_7[6][0]
#                                                                  lstm_7[6][2]
#                                                                  dot_121[0][0]
#                                                                  lstm_7[7][0]
#                                                                  lstm_7[7][2]
#                                                                  dot_122[0][0]
#                                                                  lstm_7[8][0]
#                                                                  lstm_7[8][2]
#                                                                  dot_123[0][0]
#                                                                  lstm_7[9][0]
#                                                                  lstm_7[9][2]
#                                                                  dot_124[0][0]
#                                                                  lstm_7[10][0]
#                                                                  lstm_7[10][2]
#                                                                  dot_125[0][0]
#                                                                  lstm_7[11][0]
#                                                                  lstm_7[11][2]
#                                                                  dot_126[0][0]
#                                                                  lstm_7[12][0]
#                                                                  lstm_7[12][2]
#                                                                  dot_127[0][0]
#                                                                  lstm_7[13][0]
#                                                                  lstm_7[13][2]
#                                                                  dot_128[0][0]
#                                                                  lstm_7[14][0]
#                                                                  lstm_7[14][2]
#                                                                  dot_129[0][0]
#                                                                  lstm_7[15][0]
#                                                                  lstm_7[15][2]
#                                                                  dot_130[0][0]
#                                                                  lstm_7[16][0]
#                                                                  lstm_7[16][2]
#                                                                  dot_131[0][0]
#                                                                  lstm_7[17][0]
#                                                                  lstm_7[17][2]
#                                                                  dot_132[0][0]
#                                                                  lstm_7[18][0]
#                                                                  lstm_7[18][2]
#                                                                  dot_133[0][0]
#                                                                  lstm_7[19][0]
#                                                                  lstm_7[19][2]
#                                                                  dot_134[0][0]
#                                                                  lstm_7[20][0]
#                                                                  lstm_7[20][2]
#                                                                  dot_135[0][0]
#                                                                  lstm_7[21][0]
#                                                                  lstm_7[21][2]
#                                                                  dot_136[0][0]
#                                                                  lstm_7[22][0]
#                                                                  lstm_7[22][2]
#                                                                  dot_137[0][0]
#                                                                  lstm_7[23][0]
#                                                                  lstm_7[23][2]
#                                                                  dot_138[0][0]
#                                                                  lstm_7[24][0]
#                                                                  lstm_7[24][2]
#                                                                  dot_139[0][0]
#                                                                  lstm_7[25][0]
#                                                                  lstm_7[25][2]
#                                                                  dot_140[0][0]
#                                                                  lstm_7[26][0]
#                                                                  lstm_7[26][2]
#                                                                  dot_141[0][0]
#                                                                  lstm_7[27][0]
#                                                                  lstm_7[27][2]
#                                                                  dot_142[0][0]
#                                                                  lstm_7[28][0]
#                                                                  lstm_7[28][2]
#                                                                  dot_143[0][0]
#                                                                  lstm_7[29][0]
#                                                                  lstm_7[29][2]
#                                                                  dot_144[0][0]
#                                                                  lstm_7[30][0]
#                                                                  lstm_7[30][2]
#                                                                  dot_145[0][0]
#                                                                  lstm_7[31][0]
#                                                                  lstm_7[31][2]
#                                                                  dot_146[0][0]
#                                                                  lstm_7[32][0]
#                                                                  lstm_7[32][2]
#                                                                  dot_147[0][0]
#                                                                  lstm_7[33][0]
#                                                                  lstm_7[33][2]
#                                                                  dot_148[0][0]
#                                                                  lstm_7[34][0]
#                                                                  lstm_7[34][2]
#                                                                  dot_149[0][0]
#                                                                  lstm_7[35][0]
#                                                                  lstm_7[35][2]
#                                                                  dot_150[0][0]
#                                                                  lstm_7[36][0]
#                                                                  lstm_7[36][2]
#                                                                  dot_151[0][0]
#                                                                  lstm_7[37][0]
#                                                                  lstm_7[37][2]
#                                                                  dot_152[0][0]
#                                                                  lstm_7[38][0]
#                                                                  lstm_7[38][2]
#                                                                  dot_153[0][0]
#                                                                  lstm_7[39][0]
#                                                                  lstm_7[39][2]
#                                                                  dot_154[0][0]
#                                                                  lstm_7[40][0]
#                                                                  lstm_7[40][2]
#                                                                  dot_155[0][0]
#                                                                  lstm_7[41][0]
#                                                                  lstm_7[41][2]
#                                                                  dot_156[0][0]
#                                                                  lstm_7[42][0]
#                                                                  lstm_7[42][2]
#                                                                  dot_157[0][0]
#                                                                  lstm_7[43][0]
#                                                                  lstm_7[43][2]
#                                                                  dot_158[0][0]
#                                                                  lstm_7[44][0]
#                                                                  lstm_7[44][2]
#                                                                  dot_159[0][0]
#                                                                  lstm_7[45][0]
#                                                                  lstm_7[45][2]
#                                                                  dot_160[0][0]
#                                                                  lstm_7[46][0]
#                                                                  lstm_7[46][2]
#                                                                  dot_161[0][0]
#                                                                  lstm_7[47][0]
#                                                                  lstm_7[47][2]
#                                                                  dot_162[0][0]
#                                                                  lstm_7[48][0]
#                                                                  lstm_7[48][2]
# __________________________________________________________________________________________________
# repeat_vector_114 (RepeatVector (None, 500, 1024)    0           lstm_7[0][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_227 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_114 (Concatenate)   (None, 500, 1536)    0           repeat_vector_114[0][0]
#                                                                  tf_op_layer_strided_slice_227[0][
# __________________________________________________________________________________________________
# dense_346 (Dense)               (None, 500, 512)     786944      concatenate_114[0][0]
# __________________________________________________________________________________________________
# dense_347 (Dense)               (None, 500, 50)      25650       dense_346[0][0]
# __________________________________________________________________________________________________
# dense_348 (Dense)               (None, 500, 1)       51          dense_347[0][0]
# __________________________________________________________________________________________________
# lambda_114 (Lambda)             (None, 500, 1)       0           dense_348[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_228 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_114 (Dot)                   (None, 1, 512)       0           lambda_114[0][0]
#                                                                  tf_op_layer_strided_slice_228[0][
# __________________________________________________________________________________________________
# repeat_vector_115 (RepeatVector (None, 500, 1024)    0           lstm_7[1][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_229 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_115 (Concatenate)   (None, 500, 1536)    0           repeat_vector_115[0][0]
#                                                                  tf_op_layer_strided_slice_229[0][
# __________________________________________________________________________________________________
# dense_349 (Dense)               (None, 500, 512)     786944      concatenate_115[0][0]
# __________________________________________________________________________________________________
# dense_350 (Dense)               (None, 500, 50)      25650       dense_349[0][0]
# __________________________________________________________________________________________________
# dense_351 (Dense)               (None, 500, 1)       51          dense_350[0][0]
# __________________________________________________________________________________________________
# lambda_115 (Lambda)             (None, 500, 1)       0           dense_351[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_230 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_115 (Dot)                   (None, 1, 512)       0           lambda_115[0][0]
#                                                                  tf_op_layer_strided_slice_230[0][
# __________________________________________________________________________________________________
# repeat_vector_116 (RepeatVector (None, 500, 1024)    0           lstm_7[2][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_231 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_116 (Concatenate)   (None, 500, 1536)    0           repeat_vector_116[0][0]
#                                                                  tf_op_layer_strided_slice_231[0][
# __________________________________________________________________________________________________
# dense_352 (Dense)               (None, 500, 512)     786944      concatenate_116[0][0]
# __________________________________________________________________________________________________
# dense_353 (Dense)               (None, 500, 50)      25650       dense_352[0][0]
# __________________________________________________________________________________________________
# dense_354 (Dense)               (None, 500, 1)       51          dense_353[0][0]
# __________________________________________________________________________________________________
# lambda_116 (Lambda)             (None, 500, 1)       0           dense_354[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_232 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_116 (Dot)                   (None, 1, 512)       0           lambda_116[0][0]
#                                                                  tf_op_layer_strided_slice_232[0][
# __________________________________________________________________________________________________
# repeat_vector_117 (RepeatVector (None, 500, 1024)    0           lstm_7[3][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_233 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_117 (Concatenate)   (None, 500, 1536)    0           repeat_vector_117[0][0]
#                                                                  tf_op_layer_strided_slice_233[0][
# __________________________________________________________________________________________________
# dense_355 (Dense)               (None, 500, 512)     786944      concatenate_117[0][0]
# __________________________________________________________________________________________________
# dense_356 (Dense)               (None, 500, 50)      25650       dense_355[0][0]
# __________________________________________________________________________________________________
# dense_357 (Dense)               (None, 500, 1)       51          dense_356[0][0]
# __________________________________________________________________________________________________
# lambda_117 (Lambda)             (None, 500, 1)       0           dense_357[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_234 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_117 (Dot)                   (None, 1, 512)       0           lambda_117[0][0]
#                                                                  tf_op_layer_strided_slice_234[0][
# __________________________________________________________________________________________________
# repeat_vector_118 (RepeatVector (None, 500, 1024)    0           lstm_7[4][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_235 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_118 (Concatenate)   (None, 500, 1536)    0           repeat_vector_118[0][0]
#                                                                  tf_op_layer_strided_slice_235[0][
# __________________________________________________________________________________________________
# dense_358 (Dense)               (None, 500, 512)     786944      concatenate_118[0][0]
# __________________________________________________________________________________________________
# dense_359 (Dense)               (None, 500, 50)      25650       dense_358[0][0]
# __________________________________________________________________________________________________
# dense_360 (Dense)               (None, 500, 1)       51          dense_359[0][0]
# __________________________________________________________________________________________________
# lambda_118 (Lambda)             (None, 500, 1)       0           dense_360[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_236 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_118 (Dot)                   (None, 1, 512)       0           lambda_118[0][0]
#                                                                  tf_op_layer_strided_slice_236[0][
# __________________________________________________________________________________________________
# repeat_vector_119 (RepeatVector (None, 500, 1024)    0           lstm_7[5][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_237 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_119 (Concatenate)   (None, 500, 1536)    0           repeat_vector_119[0][0]
#                                                                  tf_op_layer_strided_slice_237[0][
# __________________________________________________________________________________________________
# dense_361 (Dense)               (None, 500, 512)     786944      concatenate_119[0][0]
# __________________________________________________________________________________________________
# dense_362 (Dense)               (None, 500, 50)      25650       dense_361[0][0]
# __________________________________________________________________________________________________
# dense_363 (Dense)               (None, 500, 1)       51          dense_362[0][0]
# __________________________________________________________________________________________________
# lambda_119 (Lambda)             (None, 500, 1)       0           dense_363[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_238 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_119 (Dot)                   (None, 1, 512)       0           lambda_119[0][0]
#                                                                  tf_op_layer_strided_slice_238[0][
# __________________________________________________________________________________________________
# repeat_vector_120 (RepeatVector (None, 500, 1024)    0           lstm_7[6][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_239 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_120 (Concatenate)   (None, 500, 1536)    0           repeat_vector_120[0][0]
#                                                                  tf_op_layer_strided_slice_239[0][
# __________________________________________________________________________________________________
# dense_364 (Dense)               (None, 500, 512)     786944      concatenate_120[0][0]
# __________________________________________________________________________________________________
# dense_365 (Dense)               (None, 500, 50)      25650       dense_364[0][0]
# __________________________________________________________________________________________________
# dense_366 (Dense)               (None, 500, 1)       51          dense_365[0][0]
# __________________________________________________________________________________________________
# lambda_120 (Lambda)             (None, 500, 1)       0           dense_366[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_240 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_120 (Dot)                   (None, 1, 512)       0           lambda_120[0][0]
#                                                                  tf_op_layer_strided_slice_240[0][
# __________________________________________________________________________________________________
# repeat_vector_121 (RepeatVector (None, 500, 1024)    0           lstm_7[7][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_241 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_121 (Concatenate)   (None, 500, 1536)    0           repeat_vector_121[0][0]
#                                                                  tf_op_layer_strided_slice_241[0][
# __________________________________________________________________________________________________
# dense_367 (Dense)               (None, 500, 512)     786944      concatenate_121[0][0]
# __________________________________________________________________________________________________
# dense_368 (Dense)               (None, 500, 50)      25650       dense_367[0][0]
# __________________________________________________________________________________________________
# dense_369 (Dense)               (None, 500, 1)       51          dense_368[0][0]
# __________________________________________________________________________________________________
# lambda_121 (Lambda)             (None, 500, 1)       0           dense_369[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_242 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_121 (Dot)                   (None, 1, 512)       0           lambda_121[0][0]
#                                                                  tf_op_layer_strided_slice_242[0][
# __________________________________________________________________________________________________
# repeat_vector_122 (RepeatVector (None, 500, 1024)    0           lstm_7[8][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_243 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_122 (Concatenate)   (None, 500, 1536)    0           repeat_vector_122[0][0]
#                                                                  tf_op_layer_strided_slice_243[0][
# __________________________________________________________________________________________________
# dense_370 (Dense)               (None, 500, 512)     786944      concatenate_122[0][0]
# __________________________________________________________________________________________________
# dense_371 (Dense)               (None, 500, 50)      25650       dense_370[0][0]
# __________________________________________________________________________________________________
# dense_372 (Dense)               (None, 500, 1)       51          dense_371[0][0]
# __________________________________________________________________________________________________
# lambda_122 (Lambda)             (None, 500, 1)       0           dense_372[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_244 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_122 (Dot)                   (None, 1, 512)       0           lambda_122[0][0]
#                                                                  tf_op_layer_strided_slice_244[0][
# __________________________________________________________________________________________________
# repeat_vector_123 (RepeatVector (None, 500, 1024)    0           lstm_7[9][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_245 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_123 (Concatenate)   (None, 500, 1536)    0           repeat_vector_123[0][0]
#                                                                  tf_op_layer_strided_slice_245[0][
# __________________________________________________________________________________________________
# dense_373 (Dense)               (None, 500, 512)     786944      concatenate_123[0][0]
# __________________________________________________________________________________________________
# dense_374 (Dense)               (None, 500, 50)      25650       dense_373[0][0]
# __________________________________________________________________________________________________
# dense_375 (Dense)               (None, 500, 1)       51          dense_374[0][0]
# __________________________________________________________________________________________________
# lambda_123 (Lambda)             (None, 500, 1)       0           dense_375[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_246 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_123 (Dot)                   (None, 1, 512)       0           lambda_123[0][0]
#                                                                  tf_op_layer_strided_slice_246[0][
# __________________________________________________________________________________________________
# repeat_vector_124 (RepeatVector (None, 500, 1024)    0           lstm_7[10][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_247 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_124 (Concatenate)   (None, 500, 1536)    0           repeat_vector_124[0][0]
#                                                                  tf_op_layer_strided_slice_247[0][
# __________________________________________________________________________________________________
# dense_376 (Dense)               (None, 500, 512)     786944      concatenate_124[0][0]
# __________________________________________________________________________________________________
# dense_377 (Dense)               (None, 500, 50)      25650       dense_376[0][0]
# __________________________________________________________________________________________________
# dense_378 (Dense)               (None, 500, 1)       51          dense_377[0][0]
# __________________________________________________________________________________________________
# lambda_124 (Lambda)             (None, 500, 1)       0           dense_378[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_248 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_124 (Dot)                   (None, 1, 512)       0           lambda_124[0][0]
#                                                                  tf_op_layer_strided_slice_248[0][
# __________________________________________________________________________________________________
# repeat_vector_125 (RepeatVector (None, 500, 1024)    0           lstm_7[11][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_249 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_125 (Concatenate)   (None, 500, 1536)    0           repeat_vector_125[0][0]
#                                                                  tf_op_layer_strided_slice_249[0][
# __________________________________________________________________________________________________
# dense_379 (Dense)               (None, 500, 512)     786944      concatenate_125[0][0]
# __________________________________________________________________________________________________
# dense_380 (Dense)               (None, 500, 50)      25650       dense_379[0][0]
# __________________________________________________________________________________________________
# dense_381 (Dense)               (None, 500, 1)       51          dense_380[0][0]
# __________________________________________________________________________________________________
# lambda_125 (Lambda)             (None, 500, 1)       0           dense_381[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_250 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_125 (Dot)                   (None, 1, 512)       0           lambda_125[0][0]
#                                                                  tf_op_layer_strided_slice_250[0][
# __________________________________________________________________________________________________
# repeat_vector_126 (RepeatVector (None, 500, 1024)    0           lstm_7[12][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_251 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_126 (Concatenate)   (None, 500, 1536)    0           repeat_vector_126[0][0]
#                                                                  tf_op_layer_strided_slice_251[0][
# __________________________________________________________________________________________________
# dense_382 (Dense)               (None, 500, 512)     786944      concatenate_126[0][0]
# __________________________________________________________________________________________________
# dense_383 (Dense)               (None, 500, 50)      25650       dense_382[0][0]
# __________________________________________________________________________________________________
# dense_384 (Dense)               (None, 500, 1)       51          dense_383[0][0]
# __________________________________________________________________________________________________
# lambda_126 (Lambda)             (None, 500, 1)       0           dense_384[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_252 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_126 (Dot)                   (None, 1, 512)       0           lambda_126[0][0]
#                                                                  tf_op_layer_strided_slice_252[0][
# __________________________________________________________________________________________________
# repeat_vector_127 (RepeatVector (None, 500, 1024)    0           lstm_7[13][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_253 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_127 (Concatenate)   (None, 500, 1536)    0           repeat_vector_127[0][0]
#                                                                  tf_op_layer_strided_slice_253[0][
# __________________________________________________________________________________________________
# dense_385 (Dense)               (None, 500, 512)     786944      concatenate_127[0][0]
# __________________________________________________________________________________________________
# dense_386 (Dense)               (None, 500, 50)      25650       dense_385[0][0]
# __________________________________________________________________________________________________
# dense_387 (Dense)               (None, 500, 1)       51          dense_386[0][0]
# __________________________________________________________________________________________________
# lambda_127 (Lambda)             (None, 500, 1)       0           dense_387[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_254 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_127 (Dot)                   (None, 1, 512)       0           lambda_127[0][0]
#                                                                  tf_op_layer_strided_slice_254[0][
# __________________________________________________________________________________________________
# repeat_vector_128 (RepeatVector (None, 500, 1024)    0           lstm_7[14][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_255 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_128 (Concatenate)   (None, 500, 1536)    0           repeat_vector_128[0][0]
#                                                                  tf_op_layer_strided_slice_255[0][
# __________________________________________________________________________________________________
# dense_388 (Dense)               (None, 500, 512)     786944      concatenate_128[0][0]
# __________________________________________________________________________________________________
# dense_389 (Dense)               (None, 500, 50)      25650       dense_388[0][0]
# __________________________________________________________________________________________________
# dense_390 (Dense)               (None, 500, 1)       51          dense_389[0][0]
# __________________________________________________________________________________________________
# lambda_128 (Lambda)             (None, 500, 1)       0           dense_390[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_256 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_128 (Dot)                   (None, 1, 512)       0           lambda_128[0][0]
#                                                                  tf_op_layer_strided_slice_256[0][
# __________________________________________________________________________________________________
# repeat_vector_129 (RepeatVector (None, 500, 1024)    0           lstm_7[15][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_257 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# lambda_157 (Lambda)             (None, 500, 1)       0           dense_477[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_314 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_157 (Dot)                   (None, 1, 512)       0           lambda_157[0][0]
#                                                                  tf_op_layer_strided_slice_314[0][
# __________________________________________________________________________________________________
# repeat_vector_158 (RepeatVector (None, 500, 1024)    0           lstm_7[44][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_315 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_158 (Concatenate)   (None, 500, 1536)    0           repeat_vector_158[0][0]
#                                                                  tf_op_layer_strided_slice_315[0][
# __________________________________________________________________________________________________
# dense_478 (Dense)               (None, 500, 512)     786944      concatenate_158[0][0]
# __________________________________________________________________________________________________
# dense_479 (Dense)               (None, 500, 50)      25650       dense_478[0][0]
# __________________________________________________________________________________________________
# dense_480 (Dense)               (None, 500, 1)       51          dense_479[0][0]
# __________________________________________________________________________________________________
# lambda_158 (Lambda)             (None, 500, 1)       0           dense_480[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_316 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_158 (Dot)                   (None, 1, 512)       0           lambda_158[0][0]
#                                                                  tf_op_layer_strided_slice_316[0][
# __________________________________________________________________________________________________
# repeat_vector_159 (RepeatVector (None, 500, 1024)    0           lstm_7[45][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_317 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_159 (Concatenate)   (None, 500, 1536)    0           repeat_vector_159[0][0]
#                                                                  tf_op_layer_strided_slice_317[0][
# __________________________________________________________________________________________________
# dense_481 (Dense)               (None, 500, 512)     786944      concatenate_159[0][0]
# __________________________________________________________________________________________________
# dense_482 (Dense)               (None, 500, 50)      25650       dense_481[0][0]
# __________________________________________________________________________________________________
# dense_483 (Dense)               (None, 500, 1)       51          dense_482[0][0]
# __________________________________________________________________________________________________
# lambda_159 (Lambda)             (None, 500, 1)       0           dense_483[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_318 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_159 (Dot)                   (None, 1, 512)       0           lambda_159[0][0]
#                                                                  tf_op_layer_strided_slice_318[0][
# __________________________________________________________________________________________________
# repeat_vector_160 (RepeatVector (None, 500, 1024)    0           lstm_7[46][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_319 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_160 (Concatenate)   (None, 500, 1536)    0           repeat_vector_160[0][0]
#                                                                  tf_op_layer_strided_slice_319[0][
# __________________________________________________________________________________________________
# dense_484 (Dense)               (None, 500, 512)     786944      concatenate_160[0][0]
# __________________________________________________________________________________________________
# dense_485 (Dense)               (None, 500, 50)      25650       dense_484[0][0]
# __________________________________________________________________________________________________
# dense_486 (Dense)               (None, 500, 1)       51          dense_485[0][0]
# __________________________________________________________________________________________________
# lambda_160 (Lambda)             (None, 500, 1)       0           dense_486[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_320 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_160 (Dot)                   (None, 1, 512)       0           lambda_160[0][0]
#                                                                  tf_op_layer_strided_slice_320[0][
# __________________________________________________________________________________________________
# repeat_vector_161 (RepeatVector (None, 500, 1024)    0           lstm_7[47][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_321 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_161 (Concatenate)   (None, 500, 1536)    0           repeat_vector_161[0][0]
#                                                                  tf_op_layer_strided_slice_321[0][
# __________________________________________________________________________________________________
# dense_487 (Dense)               (None, 500, 512)     786944      concatenate_161[0][0]
# __________________________________________________________________________________________________
# dense_488 (Dense)               (None, 500, 50)      25650       dense_487[0][0]
# __________________________________________________________________________________________________
# dense_489 (Dense)               (None, 500, 1)       51          dense_488[0][0]
# __________________________________________________________________________________________________
# lambda_161 (Lambda)             (None, 500, 1)       0           dense_489[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_322 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_161 (Dot)                   (None, 1, 512)       0           lambda_161[0][0]
#                                                                  tf_op_layer_strided_slice_322[0][
# __________________________________________________________________________________________________
# repeat_vector_162 (RepeatVector (None, 500, 1024)    0           lstm_7[48][2]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_323 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# concatenate_162 (Concatenate)   (None, 500, 1536)    0           repeat_vector_162[0][0]
#                                                                  tf_op_layer_strided_slice_323[0][
# __________________________________________________________________________________________________
# dense_490 (Dense)               (None, 500, 512)     786944      concatenate_162[0][0]
# __________________________________________________________________________________________________
# dense_491 (Dense)               (None, 500, 50)      25650       dense_490[0][0]
# __________________________________________________________________________________________________
# dense_492 (Dense)               (None, 500, 1)       51          dense_491[0][0]
# __________________________________________________________________________________________________
# lambda_162 (Lambda)             (None, 500, 1)       0           dense_492[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_324 ( [(None, 500, 512)]   0           lstm_6[0][0]
# __________________________________________________________________________________________________
# dot_162 (Dot)                   (None, 1, 512)       0           lambda_162[0][0]
#                                                                  tf_op_layer_strided_slice_324[0][
# __________________________________________________________________________________________________
# dense_342 (Dense)               (None, 69070)        70796750    lstm_7[0][0]
#                                                                  lstm_7[1][0]
#                                                                  lstm_7[2][0]
#                                                                  lstm_7[3][0]
#                                                                  lstm_7[4][0]
#                                                                  lstm_7[5][0]
#                                                                  lstm_7[6][0]
#                                                                  lstm_7[7][0]
#                                                                  lstm_7[8][0]
#                                                                  lstm_7[9][0]
#                                                                  lstm_7[10][0]
#                                                                  lstm_7[11][0]
#                                                                  lstm_7[12][0]
#                                                                  lstm_7[13][0]
#                                                                  lstm_7[14][0]
#                                                                  lstm_7[15][0]
#                                                                  lstm_7[16][0]
#                                                                  lstm_7[17][0]
#                                                                  lstm_7[18][0]
#                                                                  lstm_7[19][0]
#                                                                  lstm_7[20][0]
#                                                                  lstm_7[21][0]
#                                                                  lstm_7[22][0]
#                                                                  lstm_7[23][0]
#                                                                  lstm_7[24][0]
#                                                                  lstm_7[25][0]
#                                                                  lstm_7[26][0]
#                                                                  lstm_7[27][0]
#                                                                  lstm_7[28][0]
#                                                                  lstm_7[29][0]
#                                                                  lstm_7[30][0]
#                                                                  lstm_7[31][0]
#                                                                  lstm_7[32][0]
#                                                                  lstm_7[33][0]
#                                                                  lstm_7[34][0]
#                                                                  lstm_7[35][0]
#                                                                  lstm_7[36][0]
#                                                                  lstm_7[37][0]
#                                                                  lstm_7[38][0]
#                                                                  lstm_7[39][0]
#                                                                  lstm_7[40][0]
#                                                                  lstm_7[41][0]
#                                                                  lstm_7[42][0]
#                                                                  lstm_7[43][0]
#                                                                  lstm_7[44][0]
#                                                                  lstm_7[45][0]
#                                                                  lstm_7[46][0]
#                                                                  lstm_7[47][0]
#                                                                  lstm_7[48][0]
#                                                                  lstm_7[49][0]
# ==================================================================================================
# Total params: 196,844,936
# Trainable params: 196,844,936
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model[0].compile(loss='categorical_crossentropy', optimizer=Adam(lr=lr), metrics=['accuracy'],experimental_run_tf_function=False)
unit = 200
checkpoint_path =  drive_path + f'/{n_first_content}_{n_first_headline}_remove_stop_attention_val_loss_watch:epoch:{epoch_num},lr={lr},{optimizer},batch_size:{batch_size},LSTM_units:{unit},dataset:{type_dataset},dropout:{dropout_rate}.hdf5'
callback_list = [
  ModelCheckpoint(checkpoint_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min'), 
  EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=1),
  # ReduceLROnPlateau(monitor='val_loss', factor=0.95, patience=2, min_lr=1e-10),
]

# %%
for epoch,batch in [[30,64]] :
  training_generator_seq = SequenceGenerator(np.array(X_train),np.array(y_train),batch,vocab_size,0)
  validation_generator_seq = SequenceGenerator(np.array(X_val),np.array(y_val),batch,vocab_size,0)
  model[0].fit(x=training_generator_seq,validation_data=validation_generator_seq,callbacks=callback_list,epochs=epoch)
# Out:
# Epoch 1/30

# %% [markdown]
# # PREDICT ATTEN MODEL

# %%
# !pip install rouge
from rouge import Rouge 
def evaluate_result(gold_sum,pred_sum) : 
  rouge = Rouge()
  avg_scores = rouge.get_scores(pred_sum, gold_sum, avg=True)
  return avg_scores
# Out:
# Collecting rouge
#   Downloading https://files.pythonhosted.org/packages/43/cc/e18e33be20971ff73a056ebdb023476b5a545e744e3fc22acd8c758f1e0d/rouge-1.0.0-py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from rouge) (1.12.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.0

# %%
def pred(n_batch,generator,model) :
  pred_sentences = []
  for i in range(len(generator)) :
    output = np.array(model.predict(generator[i])).swapaxes(0,1).tolist()
    for pred in output:
      decoded_sentence  = ''
      for token in pred :
        sampled_token_index = np.argmax(token)
        if(sampled_token_index == 0) :
          continue
        decoded_sentence = decoded_sentence + " " + rev_dict_t[sampled_token_index]
      pred_sentences.append(decoded_sentence.strip())
  return pred_sentences

# %%
def evaluate_result(gold_sum,pred_sum) : 
  rouge = Rouge()
  avg_scores = rouge.get_scores(pred_sum, gold_sum, avg=True)
  return avg_scores

# %%
 model[0].save(f"/content/v2.0_normal_best_{n_first_content}_{n_first_headline}_attention_best.h5")

# %%
n_batch = 100
test_generator = SequenceGenerator(np.array(X_test),np.array(y_test),n_batch,vocab_size,1)
training_generator = SequenceGenerator(np.array(X_train),np.array(y_train),n_batch,vocab_size,1)
validation_generator = SequenceGenerator(np.array(X_val),np.array(y_val),n_batch,vocab_size,1)
test_pred = pred(n_batch,test_generator,modelX)
rouge = {}
rouge["test"] = evaluate_result(test_pred,gold_sum_test)
print(rouge["test"])
train_pred = pred(n_batch,training_generator)
rouge["train"] = evaluate_result(train_pred,gold_sum_train)
print(rouge["train"])
val_pred = pred(n_batch,validation_generator)
rouge["val"] = evaluate_result(val_pred,gold_sum_val)
print(rouge["val"])
